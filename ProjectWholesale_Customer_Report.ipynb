# %% [markdown]
# ![Screenshot 2024-06-20 105037.png](data:image/png;base64,...)

# %% [markdown]
# # List Of Tables
# - Table 1: Displaying top 5 rows
# - Table 2 : Displaying last 5 rows
# - Table 3: Statistical Summary for numeric columns
# - Table 4: Statistical Summary for categorical columns
# - Table 5: Finding the number of null values
# - Table 6: Checking Null Values
# - Table 7: Removing Outliers

# %% [markdown]
# # PROBLEM STATEMENT
#
# A wholesale distributor operating in different regions of Portugal has information on annual spending of several items in their stores across different regions and channels. The data consists of 440 large retailers’ annual spending on 6 different varieties of productsin 3 different regions (Lisbon, Oporto, Other) and across different sales channel (Hotel, Retail).
#
# Data Description:
# - Buyer/Spender- ID's of customers
# - Region- Region of the distributor
# - Fresh- spending on Fresh Vegetables
# - Milk- spending on milk
# - Grocery- spending on grocery
# - Frozen- spending on frozen food
# - Detergents_paper- spending on detergents and toilet paper
# - Delicatessen- spending on instant foods

# %% [markdown]
# # Loading the necessary libraries.

# %% [markdown]
# ## 1-	Display the top 5 rows.

# %% [markdown]
# ![Screenshot 2024-06-23 104123.png](data:image/png;base64,...)

# %% [markdown]
# ## 2-	Display the last 5 rows

# %%
# Out:
#      Buyer/Spender Channel Region  Fresh   Milk  Grocery   Frozen  \
# 435            436   Hotel  Other  29703  12051    16027  13135.0
# 436            437   Hotel  Other  39228   1431      764   4510.0
# 437            438  Retail  Other  14531  15488    30243    437.0
# 438            439   Hotel  Other  10290   1981     2232   1038.0
# 439            440   Hotel  Other   2787   1698     2510     65.0
#
#      Detergents_Paper  Delicatessen
# 435             182.0        2204.0
# 436              93.0        2346.0
# 437           14841.0        1867.0
# 438             168.0        2125.0
# 439             477.0          52.0

# %% [markdown]
# #### Table 2: Last 5 rows

# %% [markdown]
# ### Observations:
# - There is significant spending on Fresh items, especially for Buyer/Spender 437 (Hotel, Other) with 39,228 units and Buyer/Spender 435 (Hotel, Other) with 29,703 units.
# - Buyer/Spender 438 (Retail, Other) has a notably high expenditure on Milk (15,488 units) and Grocery (30,243 units), compared to much lower spending by other buyers, such as Buyer/Spender 436 (Hotel, Other) who spent only 1,431 units on Milk and 764 units on Grocery.
# - Buyer/Spender 435 (Hotel, Other) stands out with a high expenditure on Frozen items (13,135 units).
# - Across the board, spending on Detergents_Paper is relatively low, with the highest being 14841 units by Buyer/Spender 438 (Retail, Other) and the lowest being 93 units by Buyer/Spender 436 (Hotel, Other).

# %% [markdown]
# ### 3. Check the shape of dataset.
#  -  The dataset contains 440 rows and 9 columns.

# %% [markdown]
# ### 4. Check the datatypes of each feature.

# %% [markdown]
# Datatypes of each feature:
# - Buyer/Spender         (int)
# - Channel              (object)
# - Region               (object)
# - Fresh                (object)
# - Milk                  (int)
# - Grocery               (int)
# - Frozen              (float)
# - Detergents_Paper    (float)
# - Delicatessen        (float)
# ##### The dataset contains a mix of integer, float, and object (string) data types, indicating that it includes both categorical and numerical data.

# %% [markdown]
# ## 5- Check the Statistical summary

# %% [markdown]
# Statistical summary of the dataset:
#        Buyer/Spender           Milk       Grocery        Frozen  \
# count     440.000000     440.000000    440.000000    437.000000
# mean      220.500000    6035.779545   7951.277273   3085.638444
# std       127.161315    8964.929649   9503.162829   4867.744145
# min         1.000000       1.000000      3.000000     25.000000
# 25%       110.750000    1525.250000   2153.000000    744.000000
# 50%       220.500000    3641.000000   4755.500000   1535.000000
# 75%       330.250000    7217.500000  10655.750000   3570.000000
# max       440.000000  112400.000000  92780.000000  60869.000000
#
#        Detergents_Paper  Delicatessen
# count        439.000000    438.000000
# mean        3773.747153   1531.057078
# std        19364.886053   2825.044262
# min            3.000000      3.000000
# 25%          256.500000    411.250000
# 50%          813.000000    971.000000
# 75%         3956.000000   1822.750000
# max       396100.000000  47943.000000

# %% [markdown]
# #### Table 4: Statistical Summary for categorical columns.
# ### Observations:

# %% [markdown]
# ##### 1.Channel Distribution:
# - There are 437 entries for the Channel column.
# - The dataset includes 2 unique channels.
# - The most frequent channel is "Hotel," appearing 295 times, indicating that the majority of buyers/spenders are associated with hotels.
# ##### 2.Region Distribution:
# - There are 434 entries for the Region column.
# - The dataset includes 3 unique regions.
# - The most frequent region is "Other," appearing 316 times, suggesting that the "Other" region constitutes the bulk of the dataset.
# ##### 3.Fresh Category:
# - There are 440 entries for the Fresh column.
# - The dataset includes 432 unique values, indicating a high variability in spending on fresh products.
# - The most frequent value in the Fresh category is 18044, which appears only twice, emphasizing the diverse spending patterns in this category.

# %% [markdown]
# ## 6-	Check the null values

# %%
# Out:
# Null values of each column:
# Buyer/Spender       0
# Channel             3
# Region              6
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              3
# Detergents_Paper    1
# Delicatessen        2
# dtype: int64

# %% [markdown]
# #### Null Values.
# ### Observation:
# - There are missing values in several columns: 3 in Channel, 6 in Region, 3 in Frozen, 1 in Detergents_Paper, and 2 in Delicatessen whereas remaining columns does not have null values.

# %% [markdown]
# ### 7. Check the duplicate values.
# ##### There is no duplicate rows and columns.

# %% [markdown]
# ### 8. Check the anomalies or wrong entries.

# %% [markdown]
# ### Observations:
# There were non-numeric values (specifically '?') present in several columns initially.
# - After replacing '?' with NaN:
# - Fresh: 2 non-numeric values
# - Milk, Grocery, Detergents_Paper: 0 non-numeric values
# - Frozen: 3 non-numeric values
# - Delicatessen: 2 non-numeric values
# - Now replacing non-numeric values with NaN has prepared the dataset for further data cleaning and analysis.
# - Then,handling missing values using imputation strategies tailored to each column type (numeric or categorical).

# %% [markdown]
# ###  9-	Check the outliers and their authenticity

# %% [markdown]
# # 1. SPENDING ANALYSIS

# %% [markdown]
# ### i. What is the total number of buyers in the dataset?
# - Total number of buyers in the dataset: 440

# %% [markdown]
# ### ii. What is the average spending on each category (Fresh, Milk, Grocery, Frozen, Detergents_paper, Delicatessen)?
# ##### Average spending on each category:
# - Fresh               11373.279587
# - Milk                 5073.405966
# - Grocery              7236.375000
# - Frozen               2518.007194
# - Detergents_Paper     2407.901414
# - Delicatessen         1272.579805

# %%
# Out:
# <Axes: >

# %% [markdown]
# ### iii. Which category has the highest average spending?
# - The category with the highest average spending is Fresh with 11373.279586965546

# %% [markdown]
# ### iv. How many buyers spend above the average on Fresh Vegetables?
# - The number of buyers who spend above the average on Fresh vegetables is: 172

# %% [markdown]
# # 2.REGIONAL DEMAND

# %% [markdown]
# ### i. What is the total spending in each region?

# %%
# Out:
# Total spending in each region for each category:
#          Buyer/Spender     Milk  Grocery     Frozen  Detergents_Paper  \
# Region
# Lisbon          17592   397328   534652 222,550.00        577,447.00
# Oporto          13581   232764   418529 173,172.00        172,339.00
# Other           64026  1994145  2495251 927,266.00        887,089.00
#
#         Delicatessen
# Region
# Lisbon     98,496.00
# Oporto     50,668.00
# Other     511,770.00

# %% [markdown]
# ### ii. Which region has the highest spending on Milk?
# - The region with the highest spending on Milk is: Other
# - Total spending on Milk in this region: 1640849.5

# %% [markdown]
# ### iii. How does the average spending on Grocery vary across different regions?
# Average spending on Grocery in each region:
# ##### Region:
# - Lisbon --  6,717.43
# - Oporto --  8,601.13
# - Other  --  7,175.00

# %% [markdown]
# ### iv. Which region has the highest average spending per buyer?
# ##### - Average spending per buyer in each region:
# ##### Region:
# - Lisbon --  28,615.12
# - Oporto --  30,230.59
# - Other  --  30,129.91
# ##### - Region with the highest average spending per buyer: Oporto

# %% [markdown]
# # 3.CATEGORY PREFERENCE

# %% [markdown]
# ### i. What percentage of buyers spend more on Frozen food compared to Delicatessen?
# - number of buyers frozen: 290
# - total buyers: 440
# - percentage of buyers spend more on Frozen food: 65.9090909090909

# %% [markdown]
# ### ii. Which category shows the most variation in spending among buyers?
# - Category with the most variation in spending among buyers: Fresh

# %% [markdown]
# ### iii. Are there any regions where spending on Detergents_paper is significantly higher than others?
# - There are regions where spending on Detergents_paper is significantly higher: ['Other' 'Lisbon']

# %% [markdown]
# ### iv.What is the correlation between spending on Fresh and Frozen food?
# - Correlation between spending on Fresh and Frozen food: 0.3543225909934656

# %% [markdown]
# # 4. CUSTOMER SEGMENTATION

# %% [markdown]
# ### i.  What are the characteristics of the top 10% spenders in each category?

# %%
# Out:
# Characteristics of the top 10% spenders in each category:
#        Buyer/Spender          Fresh           Milk       Grocery  \
# count     152.000000     152.000000     152.000000    152.000000
# mean      209.098684   18035.473684   10481.980263  13273.967105
# std       128.705206   17553.456877   13561.268287  13370.331771
# min         5.000000       3.000000     286.000000    471.000000
# 25%        87.750000    4564.250000    3482.000000   4029.750000
# 50%       204.500000   12162.000000    6260.500000   8591.000000
# 75%       313.750000   28574.250000   12885.000000  19823.750000
# max       438.000000  112151.000000  112400.000000  92780.000000
#
#              Frozen  Detergents_Paper  Delicatessen     Cluster
# count    152.000000        152.000000    152.000000  152.000000
# mean    5369.973684       7621.763158   2634.723684    0.802632
# std     7376.769682      32471.459028   4458.291576    0.415582
# min       33.000000         15.000000      3.000000    0.000000
# ...

# %% [markdown]
# ### ii. How do spending patterns differ between high spenders and low spenders?
# Mean spending patterns for high spenders:
# - Fresh              11,917.24
# - Milk                5,369.52
# - Grocery             7,648.70
# - Frozen              2,648.77
# - Detergents_Paper    2,567.75
# - Delicatessen        1,340.96
#
# Mean spending patterns for low spenders:
# - Fresh              3,939.17
# - Milk               1,026.50
# - Grocery            1,601.33
# - Frozen               730.93
# - Detergents_Paper     223.30
# - Delicatessen         338.07

# %% [markdown]
# # 5. CROSS CATEGORY ANALYSIS

# %% [markdown]
# ### i. Is there a correlation between spending on Milk and Grocery?
# - Correlation between spending on Milk and Grocery: 0.5902889029079393

# %% [markdown]
# ### ii. Do buyers who spend more on Delicatessen also spend more on Frozen food?
# - Correlation between spending on Delicatessen and Frozen food: 0.3893341113961669

# %%
# Out:
# Correlation between spending on Delicatessen and Frozen food: 0.38975693044209864

# %% [markdown]
# ### iii. What is the combined average spending on Fresh and Milk for each region?
# Combined average spending on Fresh and Milk for each region:
# ##### Region:
# - Lisbon     16571.146667
# - Oporto     15467.604651
# - Other      18865.933602
# - Unknown    12201.500000

# %% [markdown]
# # 6.DEMAND TRENDS

# %% [markdown]
# ### i. Which region has the fastest growing spending on Fresh Vegetables?
# - Region with the highest average spending on Fresh Vegetables: Other
# - Highest average spending on Fresh Vegetables: 12555.34815906595

# %% [markdown]
# ### ii. How does the total spending on Grocery change across regions over time (if time data is available)?
# ### iii. What is the average spending per buyer in each category over a specified time period (if time data is available)?
# - ** there is no time data available.

# %% [markdown]
# # 7.BUYERS INSIGHT

# %% [markdown]
# ### i. What is the repeat purchase rate for buyers who spend above the average in at least three categories?
# - Repeat purchase rate for buyers who spend above the average in at least three categories: 0.3613636363636364

# %% [markdown]
# ### ii. How many buyers spend consistently (i.e., similar amounts) across all categories?
# - Number of buyers who spend consistently across all categories: 110

# %% [markdown]
# ### iii. Which region has the most diverse spending patterns (i.e., high variance in spending across categories)?
# - The region with the most diverse spending patterns is: Lisbon
# Average variances per region:
# ##### Region:
# - Lisbon     3.868959e+08
# - Oporto     6.199973e+07
# - Other      6.977580e+07
# - Unknown    5.543861e+07
